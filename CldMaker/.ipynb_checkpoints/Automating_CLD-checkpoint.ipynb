# %% [markdown]
# # Download Package

# %%
# !apt install python3-dev graphviz libgraphviz-dev pkg-config
# !pip install langchain pygraphviz google-search-results
# !pip install google-cloud-aiplatform --upgrade
# Out:
# The operation couldn’t be completed. Unable to locate a Java Runtime that supports apt.
# Please visit http://www.java.com for information on installing Java.
#
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Collecting langchain
#   Downloading langchain-0.0.27-py3-none-any.whl (124 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.9/124.9 kB 2.1 MB/s eta 0:00:0000:01
# Collecting pygraphviz
#   Downloading pygraphviz-1.7.zip (118 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.8/118.8 kB 1.5 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Collecting google-search-results
#   Downloading google_search_results-2.4.2.tar.gz (18 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.7/site-packages (from langchain) (2.24.0)
# Collecting pydantic
#   Downloading pydantic-2.1.1-py3-none-any.whl (370 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 370.9/370.9 kB 1.1 MB/s eta 0:00:0000:0100:01
# Collecting numpy
#   Downloading numpy-1.21.6-cp37-cp37m-macosx_10_9_x86_64.whl (16.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.9/16.9 MB 7.1 MB/s eta 0:00:0000:0100:01
# Collecting pyyaml
#   Downloading PyYAML-6.0.1-cp37-cp37m-macosx_10_9_x86_64.whl (189 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.6/189.6 kB 3.2 MB/s eta 0:00:00a 0:00:01
# Collecting sqlalchemy
#   Downloading SQLAlchemy-2.0.19-cp37-cp37m-macosx_10_9_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 2.9 MB/s eta 0:00:0000:0100:01
# Collecting typing-extensions>=4.6.1
#   Downloading typing_extensions-4.7.1-py3-none-any.whl (33 kB)
# Collecting annotated-types>=0.4.0
#   Downloading annotated_types-0.5.0-py3-none-any.whl (11 kB)
# Collecting pydantic-core==2.4.0
#   Downloading pydantic_core-2.4.0-cp37-cp37m-macosx_10_7_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 7.4 MB/s eta 0:00:00a 0:00:01m
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/site-packages (from requests->langchain) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/site-packages (from requests->langchain) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/site-packages (from requests->langchain) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/site-packages (from requests->langchain) (2.10)
# Requirement already satisfied: importlib-metadata in /Users/Georgia 1/Library/Python/3.7/lib/python/site-packages (from sqlalchemy->langchain) (5.0.0)
# Collecting greenlet!=0.4.17
#   Downloading greenlet-2.0.2-cp37-cp37m-macosx_10_15_x86_64.whl (240 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.1/240.1 kB 3.7 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: zipp>=0.5 in /Users/Georgia 1/Library/Python/3.7/lib/python/site-packages (from importlib-metadata->sqlalchemy->langchain) (3.10.0)
# Building wheels for collected packages: pygraphviz, google-search-results
#   Building wheel for pygraphviz (setup.py) ... done
#   Created wheel for pygraphviz: filename=pygraphviz-1.7-cp37-cp37m-macosx_10_15_x86_64.whl size=101582 sha256=b849306582e57f8b26f5b03e98753c2c485b1cb373769cb8ba5e124308a42d4b
#   Stored in directory: /Users/Georgia 1/Library/Caches/pip/wheels/8c/bc/0c/ac35392b72556e75107ff610cb31b313e8471918a6d280e34c
#   Building wheel for google-search-results (setup.py) ... done
#   Created wheel for google-search-results: filename=google_search_results-2.4.2-py3-none-any.whl size=32003 sha256=bb2c7bfaaabaf94e47d6271b4c8e686664c4c4582dd57005a03d92e06a33fc0c
#   Stored in directory: /Users/Georgia 1/Library/Caches/pip/wheels/62/4c/22/064d325d4b9c00fe712b1cad88b09e36e139d495000183f23e
# Successfully built pygraphviz google-search-results
# Installing collected packages: typing-extensions, pyyaml, pygraphviz, numpy, greenlet, pydantic-core, google-search-results, annotated-types, sqlalchemy, pydantic, langchain
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.4.0
#     Uninstalling typing_extensions-4.4.0:
#       Successfully uninstalled typing_extensions-4.4.0
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Successfully installed annotated-types-0.5.0 google-search-results-2.4.2 greenlet-2.0.2 langchain-0.0.27 numpy-1.21.6 pydantic-2.1.1 pydantic-core-2.4.0 pygraphviz-1.7 pyyaml-6.0.1 sqlalchemy-2.0.19 typing-extensions-4.7.1
# [notice] A new release of pip is available: 23.0.1 -> 23.2.1
# [notice] To update, run: /usr/local/opt/python/bin/python3.7 -m pip install --upgrade pip
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Collecting google-cloud-aiplatform
#   Downloading google_cloud_aiplatform-1.30.0-py2.py3-none-any.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 6.1 MB/s eta 0:00:0000:0100:01
# Collecting protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5
#   Downloading protobuf-4.24.0-cp37-abi3-macosx_10_9_universal2.whl (409 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.6/409.6 kB 2.9 MB/s eta 0:00:0000:0100:01
# Collecting google-cloud-bigquery<4.0.0dev,>=1.15.0
#   Downloading google_cloud_bigquery-3.11.4-py2.py3-none-any.whl (219 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.6/219.6 kB 3.5 MB/s eta 0:00:0000:01
# Collecting google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0
#   Downloading google_api_core-2.11.1-py3-none-any.whl (120 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.5/120.5 kB 1.0 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: packaging>=14.3 in /Users/Georgia 1/Library/Python/3.7/lib/python/site-packages (from google-cloud-aiplatform) (21.3)
# Collecting google-cloud-storage<3.0.0dev,>=1.32.0
#   Downloading google_cloud_storage-2.10.0-py2.py3-none-any.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.6/114.6 kB 3.1 MB/s eta 0:00:00
# Collecting google-cloud-resource-manager<3.0.0dev,>=1.3.3
#   Downloading google_cloud_resource_manager-1.10.3-py2.py3-none-any.whl (320 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 321.0/321.0 kB 5.1 MB/s eta 0:00:00a 0:00:01
# Collecting proto-plus<2.0.0dev,>=1.22.0
#   Downloading proto_plus-1.22.3-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.1/48.1 kB 1.1 MB/s eta 0:00:00
# Collecting shapely<2.0.0
#   Downloading Shapely-1.8.5.post1-cp37-cp37m-macosx_10_9_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 3.6 MB/s eta 0:00:0000:0100:01m
# Collecting google-auth<3.0.dev0,>=2.14.1
#   Downloading google_auth-2.22.0-py2.py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.8/181.8 kB 2.2 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /usr/local/lib/python3.7/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (2.24.0)
# Collecting googleapis-common-protos<2.0.dev0,>=1.56.2
#   Downloading googleapis_common_protos-1.60.0-py2.py3-none-any.whl (227 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.6/227.6 kB 4.4 MB/s eta 0:00:0000:01
# Collecting grpcio-status<2.0.dev0,>=1.33.2
#   Downloading grpcio_status-1.57.0-py3-none-any.whl (5.1 kB)
# Collecting grpcio<2.0dev,>=1.33.2
#   Downloading grpcio-1.57.0-cp37-cp37m-macosx_10_10_universal2.whl (9.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 8.1 MB/s eta 0:00:0000:0100:01m
# Requirement already satisfied: python-dateutil<3.0dev,>=2.7.2 in /Users/Georgia 1/Library/Python/3.7/lib/python/site-packages (from google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (2.8.2)
# Collecting google-resumable-media<3.0dev,>=0.6.0
#   Downloading google_resumable_media-2.5.0-py2.py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.7/77.7 kB 2.0 MB/s eta 0:00:00
# Collecting google-cloud-core<3.0.0dev,>=1.6.0
#   Downloading google_cloud_core-2.3.3-py2.py3-none-any.whl (29 kB)
# Collecting grpc-google-iam-v1<1.0.0dev,>=0.12.4
#   Downloading grpc_google_iam_v1-0.12.6-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/Georgia 1/Library/Python/3.7/lib/python/site-packages (from packaging>=14.3->google-cloud-aiplatform) (3.0.9)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Requirement already satisfied: urllib3<2.0 in /usr/local/lib/python3.7/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (1.24.3)
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.3.1-py3-none-any.whl (9.3 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.3/181.3 kB 2.9 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (1.15.0)
# Collecting google-crc32c<2.0dev,>=1.0
#   Downloading google_crc32c-1.5.0-cp37-cp37m-macosx_10_9_x86_64.whl (30 kB)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (2020.6.20)
# Collecting pyasn1<0.6.0,>=0.4.6
#   Downloading pyasn1-0.5.0-py2.py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.9/83.9 kB 1.7 MB/s eta 0:00:0000:01
# Installing collected packages: shapely, pyasn1, protobuf, grpcio, google-crc32c, cachetools, rsa, pyasn1-modules, proto-plus, googleapis-common-protos, google-resumable-media, grpcio-status, google-auth, grpc-google-iam-v1, google-api-core, google-cloud-core, google-cloud-storage, google-cloud-resource-manager, google-cloud-bigquery, google-cloud-aiplatform
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Successfully installed cachetools-5.3.1 google-api-core-2.11.1 google-auth-2.22.0 google-cloud-aiplatform-1.30.0 google-cloud-bigquery-3.11.4 google-cloud-core-2.3.3 google-cloud-resource-manager-1.10.3 google-cloud-storage-2.10.0 google-crc32c-1.5.0 google-resumable-media-2.5.0 googleapis-common-protos-1.60.0 grpc-google-iam-v1-0.12.6 grpcio-1.57.0 grpcio-status-1.57.0 proto-plus-1.22.3 protobuf-4.24.0 pyasn1-0.5.0 pyasn1-modules-0.3.0 rsa-4.9 shapely-1.8.5.post1
#
# [notice] A new release of pip is available: 23.0.1 -> 23.2.1
# [notice] To update, run: /usr/local/opt/python/bin/python3.7 -m pip install --upgrade pip

# %%
# !pip install openai
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Collecting openai
#   Downloading openai-0.27.8-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.6/73.6 kB 1.3 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/site-packages (from openai) (4.7.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/site-packages (from openai) (4.50.2)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.7/site-packages (from openai) (2.24.0)
# Collecting aiohttp
#   Downloading aiohttp-3.8.5-cp37-cp37m-macosx_10_9_x86_64.whl (362 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.0/362.0 kB 969.8 kB/s eta 0:00:0000:0100:01
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/site-packages (from requests>=2.20->openai) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/site-packages (from requests>=2.20->openai) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/site-packages (from requests>=2.20->openai) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/site-packages (from requests>=2.20->openai) (2.10)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.9.2-cp37-cp37m-macosx_10_9_x86_64.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 508.0 kB/s eta 0:00:00:--:--
# Collecting charset-normalizer<4.0,>=2.0
#   Downloading charset_normalizer-3.2.0-cp37-cp37m-macosx_10_9_x86_64.whl (122 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.6/122.6 kB 2.7 MB/s eta 0:00:00a 0:00:01
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp37-cp37m-macosx_10_9_x86_64.whl (36 kB)
# Requirement already satisfied: attrs>=17.3.0 in /Users/Georgia 1/Library/Python/3.7/lib/python/site-packages (from aiohttp->openai) (22.1.0)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp37-cp37m-macosx_10_9_x86_64.whl (28 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Installing collected packages: multidict, frozenlist, charset-normalizer, asynctest, async-timeout, yarl, aiosignal, aiohttp, openai
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Successfully installed aiohttp-3.8.5 aiosignal-1.3.1 async-timeout-4.0.3 asynctest-0.13.0 charset-normalizer-3.2.0 frozenlist-1.3.3 multidict-6.0.4 openai-0.27.8 yarl-1.9.2
#
# [notice] A new release of pip is available: 23.0.1 -> 23.2.1
# [notice] To update, run: /usr/local/opt/python/bin/python3.7 -m pip install --upgrade pip

# %%
# !pip install pandas
# !pip install networkx
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Collecting pandas
#   Downloading pandas-1.3.5-cp37-cp37m-macosx_10_9_x86_64.whl (11.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 11.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/Georgia 1/Library/Python/3.7/lib/python/site-packages (from pandas) (2.8.2)
# Collecting pytz>=2017.3
#   Downloading pytz-2023.3-py2.py3-none-any.whl (502 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 502.3/502.3 kB 7.4 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/site-packages (from pandas) (1.21.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Installing collected packages: pytz, pandas
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Successfully installed pandas-1.3.5 pytz-2023.3
#
# [notice] A new release of pip is available: 23.0.1 -> 23.2.1
# [notice] To update, run: /usr/local/opt/python/bin/python3.7 -m pip install --upgrade pip
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Collecting networkx
#   Downloading networkx-2.6.3-py3-none-any.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 5.7 MB/s eta 0:00:0000:0100:01
# Installing collected packages: networkx
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Successfully installed networkx-2.6.3
#
# [notice] A new release of pip is available: 23.0.1 -> 23.2.1
# [notice] To update, run: /usr/local/opt/python/bin/python3.7 -m pip install --upgrade pip

# %% [markdown]
# # Import

# %%
import IPython

app = IPython.Application.instance()
app.kernel.do_shutdown(True)
# Out:
# {'status': 'ok', 'restart': True}

# %%
SHEET_NAME = 'Sheet1'
URL = 'https://docs.google.com/spreadsheets/d/1u_Mddcwgl5rULHOHPjIFciaf5_ZriKHVXW96xrN-JpU/edit#gid=0'

# %%
import os
import json
from pprint import pprint
from typing import List, Dict, Tuple, Any, Optional, Union
# from PIL import Image

from IPython.display import display

import numpy as np
import pandas as pd
import networkx as nx

# from google.colab import auth as google_auth
# google_auth.authenticate_user()

# import gspread
# from gspread_dataframe import set_with_dataframe
# from google.auth import default

# creds, _ = default()
# gc = gspread.authorize(creds)
#import vertexai

import langchain
from langchain.prompts.prompt import PromptTemplate
from langchain.prompts.few_shot import FewShotPromptTemplate
#from langchain.llms import VertexAI
from langchain.llms import OpenAI
from langchain.chains import LLMChain, TransformChain, SequentialChain
from langchain.evaluation.criteria.eval_chain import CriteriaEvalChain

import tensorflow as tf
tf.compat.v1.enable_eager_execution()
# Out:
# ---------------------------------------------------------------------------
# PydanticUserError                         Traceback (most recent call last)
# /var/folders/05/3b7grs6n26d29szv315m2sc00000gn/T/ipykernel_53321/1318264760.py in <module>
#      22 #import vertexai
#      23
# ---> 24 import langchain
#      25 from langchain.prompts.prompt import PromptTemplate
#      26 from langchain.prompts.few_shot import FewShotPromptTemplate
#
# /usr/local/lib/python3.7/site-packages/langchain/__init__.py in <module>
#       6     __version__ = _f.read().strip()
#       7
# ----> 8 from langchain.agents import MRKLChain, ReActChain, SelfAskWithSearchChain
#       9 from langchain.chains import (
#      10     ConversationChain,
#
# /usr/local/lib/python3.7/site-packages/langchain/agents/__init__.py in <module>
#       1 """Routing chains."""
# ----> 2 from langchain.agents.agent import Agent
#       3 from langchain.agents.loading import initialize_agent
#       4 from langchain.agents.mrkl.base import MRKLChain, ZeroShotAgent
#       5 from langchain.agents.react.base import ReActChain, ReActTextWorldAgent
#
# /usr/local/lib/python3.7/site-packages/langchain/agents/agent.py in <module>
#       9 from langchain.agents.tools import Tool
#      10 from langchain.chains.base import Chain
# ---> 11 from langchain.chains.llm import LLMChain
#      12 from langchain.input import ChainedInput, get_color_mapping
#      13 from langchain.llms.base import LLM
#
# /usr/local/lib/python3.7/site-packages/langchain/chains/__init__.py in <module>
#       1 """Chains are easily reusable components which can be linked together."""
# ----> 2 from langchain.chains.conversation.base import ConversationChain
#       3 from langchain.chains.llm import LLMChain
#       4 from langchain.chains.llm_math.base import LLMMathChain
#       5 from langchain.chains.pal.base import PALChain
#
# /usr/local/lib/python3.7/site-packages/langchain/chains/conversation/base.py in <module>
#       5
#       6 from langchain.chains.base import Memory
# ----> 7 from langchain.chains.conversation.memory import ConversationBufferMemory
#       8 from langchain.chains.conversation.prompt import PROMPT
#       9 from langchain.chains.llm import LLMChain
#
# /usr/local/lib/python3.7/site-packages/langchain/chains/conversation/memory.py in <module>
#       5
#       6 from langchain.chains.base import Memory
# ----> 7 from langchain.chains.conversation.prompt import SUMMARY_PROMPT
#       8 from langchain.chains.llm import LLMChain
#       9 from langchain.llms.base import LLM
#
# /usr/local/lib/python3.7/site-packages/langchain/chains/conversation/prompt.py in <module>
#       1 # flake8: noqa
# ----> 2 from langchain.prompts.prompt import PromptTemplate
#       3
#       4 _DEFAULT_TEMPLATE = """The following is a friendly conversation between a human and an AI. The AI is talkative and provides lots of specific details from its context. If the AI does not know the answer to a question, it truthfully says it does not know.
#       5
#
# /usr/local/lib/python3.7/site-packages/langchain/prompts/__init__.py in <module>
#       1 """Prompt template classes."""
# ----> 2 from langchain.prompts.base import BasePromptTemplate
#       3 from langchain.prompts.few_shot import FewShotPromptTemplate
#       4 from langchain.prompts.loading import load_prompt
#       5 from langchain.prompts.prompt import Prompt, PromptTemplate
#
# /usr/local/lib/python3.7/site-packages/langchain/prompts/base.py in <module>
#      33
#      34
# ---> 35 class BasePromptTemplate(BaseModel, ABC):
#      36     """Base prompt should expose the format method, returning a prompt."""
#      37
#
# /usr/local/lib/python3.7/site-packages/langchain/prompts/base.py in BasePromptTemplate()
#      39     """A list of the names of the variables the prompt template expects."""
#      40
# ---> 41     @root_validator()
#      42     def validate_variable_names(cls, values: Dict) -> Dict:
#      43         """Validate variable names do not restricted names."""
#
# /usr/local/lib/python3.7/site-packages/pydantic/deprecated/class_validators.py in root_validator(pre, skip_on_failure, allow_reuse, *__args)
#     229             'If you use `@root_validator` with pre=False (the default) you MUST specify `skip_on_failure=True`.'
#     230             ' Note that `@root_validator` is deprecated and should be replaced with `@model_validator`.',
# --> 231             code='root-validator-pre-skip',
#     232         )
#     233
#
# PydanticUserError: If you use `@root_validator` with pre=False (the default) you MUST specify `skip_on_failure=True`. Note that `@root_validator` is deprecated and should be replaced with `@model_validator`.
#
# For further information visit https://errors.pydantic.dev/2.1.1/u/root-validator-pre-skip

# %% [markdown]
# # Functions

# %%
config =[
    {
        'input_variables':['dynamic_hypothesis'],
        'output_variables':['variables'],
        'prompt_prefix':'''
        Render a list of variable names from the text given.

        The variable names in
        '''
        ###Write up
    },
    {
        'input_variables':['variables','dynamic_hypothesis'],
        'output_variables':['label_graphs'],
        'prompt_prefix':'''
        Render a dot format of variable names from the text given.


        '''
        ###Write up
    }
]

# %%
def make_few_shot_prompt(
    input_variables: List[str],
    output_variables:List[str],
    prompt_prefix: str,
    examples_df: pd.DataFrame,
    variable_delimiter: str,
)-> FewShotPromptTemplate:

  all_variables = input_variables+ output_variables

  few_shot_prompt = FewShotPromptTemplate(
      examples = examples_df[all_variables].to_dict('records'),
      example_prompt = PromptTemplate(
          input_variables=all_variables,
          template = f'{variable_delimiter}\n'.join([f'{v}:{{{v}}}'
                                                  for v in all_variables]),
      ),
      prefix = prompt_prefix,
      suffix = f'{variable_delimiter}\n'.join([f'{v}:{{{v}}}'for v in input_variables]),
      input_variables = input_variables,
  )
  return few_shot_prompt

def make_few_shot_sequential_chain(
    config: List[Dict[str, Union[List[str],str]]],
    examples_df: pd.DataFrame,
    llm: langchain.llms.base.LLM,
    variable_delimiter: str ='|||'
) -> SequentialChain:

  chain_elements = []
  all_output_variables =[]
  for stage_info in config:
    input_variables = stage_info['input_variables']
    output_variables = stage_info['output_variables']
    prompt_prefix = stage_info['prompt_prefix']

    prompt = make_few_shot_prompt(input_variables,
                                  output_variables,
                                  prompt_prefix,
                                  examples_df,
                                  variable_delimiter
                                  )

  # LLM is MISO. To make the each stage MIMO, we create a SequentialChain from
  # the said LLMChain and a follow uup TransformChain that extracts the output
  # variables from the LLMChain's output. Using an output parser did not work because
  # the LLMChain can ultimately just return  one output.

  def transform_func(inputs: Dict)-> Dict:
    actual_vars_formatted = []
    actual_vars_unformatted = inputs['text'].split(variable_delimiter)
    for actual_var in actual_vars_unformatted:
      if ':' in actual_var:
        var_name, var_value = tuple(actual_var.split(':',1))
        var_name = var_name.strip('\n').strip()
        var_value = var_value.strip('\n').strip()
        actual_vars_formatted.append((var_name, var_value))
    return dict(actual_vars_formatted)

  chain_element = SequentialChain(
      input_variables = input_variables,
      output_variables = output_variables,
      chains = [
          LLMChain(prompt = prompt, llm=llm),
          TransformChain(
              input_variables=['text'],output_variables=output_variables,
              transform= transform_func
            )
      ]
  )

  chain_elements.append(chain_element)
  all_output_variables.extend(output_variables)

  full_chain = SequentialChain(
      chains = chain_elements,
      input_variables=chain_elements[0].input_variables,
      output_variables=all_output_variables,
  )
  return full_chain
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/05/3b7grs6n26d29szv315m2sc00000gn/T/ipykernel_53321/811746394.py in <module>
#       5     examples_df: pd.DataFrame,
#       6     variable_delimiter: str,
# ----> 7 )-> FewShotPromptTemplate:
#       8
#       9   all_variables = input_variables+ output_variables
#
# NameError: name 'FewShotPromptTemplate' is not defined

# %%
def apply_chain_on_df(chain: SequentialChain,
                      df: pd.DataFrame,
                      output_suffix: str = '_out') -> pd.DataFrame:

    results_df = pd.DataFrame(
        [chain(row[chain.input_variables].to_dict())
        for _,row in df.iterrows()],
        index = df.index,
    )
    results_df = results_df[chain.output_variables]
    results_df.columns = results_df.columns + f'{output_suffix}'
    return results_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/05/3b7grs6n26d29szv315m2sc00000gn/T/ipykernel_53321/745110140.py in <module>
#       1 def apply_chain_on_df(chain: SequentialChain,
#       2                       df: pd.DataFrame,
# ----> 3                       output_suffix: str = '_out') -> pd.DataFrame:
#       4
#       5     results_df = pd.DataFrame(
#
# NameError: name 'SequentialChain' is not defined

# %%
def get_df_from_sheet_url(url:str,sheet_name) -> pd.DataFrame:
  rows = gc.open_by_url(url)
  worksheet = rows.worksheet(sheet_name)

  df = pd.DataFrame(worksheet.get_all_records())
  return df

# %% [markdown]
# # Load Prompts

# %%
prompts_df = get_df_from_sheet_url(URL, SHEET_NAME)
display(prompts_df.head(2))
# Out:
#   Case                                 dynamic_hypothesis  \
# 0       The order rate decision, if it is to bring act...
# 1       A hot cup of coffee will gradually cool down t...
#
#                                            variables  \
# 0  order rate, inventory, desired inventory, adju...
# 1  coffee temperature, discrepancy, cooling rate,...
#
#                                         label_graphs
# 0  digraph{"order rate" -> "inventory" [arrowhead...
# 1

# %%
prompts_df['label_graphs'] = prompts_df['label_graphs'].str.replace(
    '{','{{',regex = False
).str.replace(
    '}','}}',regex = False
)

prompts_df['dynamic_hypothesis'] = prompts_df['dynamic_hypothesis'].str.strip('\n').str.strip(' ')

# %%
from sklearn.model_selection import train_test_split
test_percentage_slider = 50
train_df, test_df = train_test_split(prompts_df, test_size = test_percentage_slider/100.0,
                                     shuffle=False)

display(train_df)
display(test_df)
# Out:
#   Case                                 dynamic_hypothesis  \
# 0       The order rate decision, if it is to bring act...
#
#                                            variables  \
# 0  order rate, inventory, desired inventory, adju...
#
#                                         label_graphs
# 0  digraph{{"order rate" -> "inventory" [arrowhea...
#   Case                                 dynamic_hypothesis  \
# 1       A hot cup of coffee will gradually cool down t...
#
#                                            variables label_graphs
# 1  coffee temperature, discrepancy, cooling rate,...

# %%
llm = OpenAI(temperature=0, openai_api_key = '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')

#use chatGPT

full_chain = make_few_shot_sequential_chain(config, train_df, llm)

# %%
# from langchain import HuggingFaceHub, LLMChain

# # initialize Hub LLM
# hub_llm = HuggingFaceHub(
#         repo_id='google/flan-t5-xl',
#     model_kwargs={'temperature':1e-10}
# )
# full_chain = make_few_shot_sequential_chain(config, train_df, hub_llm)

# %%
results_df = apply_chain_on_df(full_chain, test_df)
results_df = pd.concat([test_df, results_df], axis = 1)
display(results_df)
# Out:
#   Case                                 dynamic_hypothesis  \
# 1       A hot cup of coffee will gradually cool down t...
#
#                                            variables label_graphs  \
# 1  coffee temperature, discrepancy, cooling rate,...
#
#                                     label_graphs_out
# 1  digraph{"coffee temperature" -> "discrepancy" ...

# %%
#Revert the escaping operation from earlier.
results_df['label_graphs'] = results_df['label_graphs'].str.replace(
    '{{','{', regex = False
).str.replace(
    '}}','}', regex = False
)
